# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

# use a headless browser (saves time)
chrome_options = Options()
chrome_options.add_argument("--headless")

# set up the broweser
driver = webdriver.Chrome(options=chrome_options)

# BOM climate data home page
driver.get("http://www.bom.gov.au/climate/data/")

# read in weather stations
station_data = pd.read_csv("weather_stations.csv")
stations = station_data["site"]

# prepare for scraping
Select(driver.find_element_by_name("ncc_obs_code_group")).select_by_value("4")
window_before = driver.window_handles[0]
select_station = driver.find_element_by_name("p_stn_num")

# empty list to capture solar scraped solar data
solar_exposure = []

# scraping loop
for station in stations:

    # clear the input field and replace with new station
    select_station.clear()
    select_station.send_keys(str(station), Keys.RETURN)

    # switch to the new window that popped up
    window_after = driver.window_handles[1]
    driver.switch_to.window(window_after)

    # attempt to read solar data and add to list; otherwise add null value
    try:
        driver.find_element_by_id("monthlyLink").click()
        exposure = driver.find_element_by_css_selector("#statsTable tr:nth-child(2) td:last-child").get_attribute("innerText")
        solar_exposure.append(exposure)
    except:
        solar_exposure.append("NaN")

    # close all but the first window
    for window in driver.window_handles[1:]:
        driver.switch_to.window(window)
        driver.close()
    driver.switch_to.window(window_before)

# end scraping, add solar exposure to stations and save
driver.close()
station_data["solar_exposure"] = solar_exposure
station_data.to_csv("station_solar_data.csv")
# Out:
# <ipython-input-96-fce1a854ad0d>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# Station 23090 success: 15.2 recorded
# Station 23037 success: 15.7 recorded
# Station 23031 success: 14.9 recorded
# Station 23000 success: 15.0 recorded
# Station 23034 success: 15.9 recorded
# Station 9999 success: 14.9 recorded
# Station 9741 success: 14.9 recorded
# Station 15590 success: 20.3 recorded
# Station 58131 success: 16.1 recorded
# Station 86147 success: 14.1 recorded
# Station 15527 success: 20.3 recorded
# Station 33002 success: 18.6 recorded
# Station 67068 success: 14.4 recorded
# Station 10244 success: 17.9 recorded
# Station 92003 success: 13.0 recorded
# Station 39006 success: 17.4 recorded
# Station 32061 success: 17.1 recorded
# Station 40428 success: 17.0 recorded
# Station 35149 success: 17.5 recorded
# Station 40223 success: 16.7 recorded
# Station 40842 success: 16.9 recorded
# Station 40214 success: 16.3 recorded
# Station 3003 success: 21.2 recorded
# Station 14629 success: 20.7 recorded
# Station 86351 success: 13.8 recorded
# Station 95003 success: 13.1 recorded
# Station 71030 success: 14.7 recorded
# Station 72091 success: 14.7 recorded
# Station 31011 success: 18.0 recorded
# Station 3040 success: 21.8 recorded
# Station 37010 success: 20.9 recorded
# Station 93036 success: 13.9 recorded
# Station 70351 success: 15.9 recorded
# Station 70014 success: 15.9 recorded
# Station 70282 success: 16.1 recorded
# Station 70015 success: 16.1 recorded
# Station 300017 failure: null value recorded
# Station 300006 failure: null value recorded
# Station 18012 success: 17.7 recorded
# Station 14703 success: 20.7 recorded
# Station 29009 success: 20.8 recorded
# Station 14090 success: 20.0 recorded
# Station 24545 success: 15.7 recorded
# Station 76031 success: 17.5 recorded
# Station 33090 success: 18.0 recorded
# Station 18052 success: 17.3 recorded
# Station 53115 success: 17.4 recorded
# Station 53048 success: 17.4 recorded
# Station 26019 success: 14.7 recorded
# Station 26021 success: 14.4 recorded
# Station 29127 success: 20.5 recorded
# Station 29126 success: 20.5 recorded
# Station 10152 success: 18.2 recorded
# Station 40282 success: 15.9 recorded
# Station 200288 failure: null value recorded
# Station 68076 success: 14.0 recorded
# Station 23321 success: 16.0 recorded
# Station 23373 success: 16.0 recorded
# Station 17043 success: 20.0 recorded
# Station 63254 success: 16.5 recorded
# Station 26089 success: 15.6 recorded
# Station 7178 success: 21.0 recorded
# Station 31076 success: 19.8 recorded
# Station 22814 success: 15.3 recorded
# Station 9592 success: 15.6 recorded
# Station 9021 success: 17.9 recorded
# Station 9034 success: 18.1 recorded
# Station 18181 success: 15.7 recorded
# Station 15666 success: 21.2 recorded
# Station 15548 success: 21.2 recorded
# Station 67033 success: 14.5 recorded
# Station 23020 success: 16.1 recorded
# Station 82039 success: 16.3 recorded
# Station 97047 success: 12.1 recorded
# Station 92094 success: 13.3 recorded
# Station 61089 success: 16.3 recorded
# Station 86104 success: 13.4 recorded
# Station 91246 success: 13.5 recorded
# Station 91116 success: 13.5 recorded
# Station 91219 success: 13.5 recorded
# Station 32037 success: 17.4 recorded
# Station 71029 success: 13.5 recorded
# Station 9109 success: 17.8 recorded
# Station 97082 success: 11.4 recorded
# Station 97067 success: 11.3 recorded
# Station 97072 success: 11.4 recorded
# Station 97048 success: 10.6 recorded
# Station 97053 success: 11.4 recorded
# Station 26082 success: 15.2 recorded
# Station 92038 success: 13.1 recorded
# Station 66062 success: 14.6 recorded
# Station 66037 success: 14.9 recorded
# Station 55327 success: 17.4 recorded
# Station 55054 success: 17.5 recorded
# Station 81049 success: 16.5 recorded
# Station 33047 success: 16.9 recorded
# Station 15135 success: 21.4 recorded
# Station 91099 success: 13.0 recorded
# Station 14925 success: 20.5 recorded
# Station 86142 success: 13.6 recorded
# Station 32040 success: 18.5 recorded
# Station 40082 success: 16.4 recorded
# Station 40457 success: 16.3 recorded
# Station 72150 success: 16.6 recorded
# Station 74114 success: 16.6 recorded
# Station 24041 success: 16.9 recorded
# Station 31108 success: 19.1 recorded
# Station 14513 success: 19.4 recorded
# Station 41525 success: 16.8 recorded
# Station 27045 success: 19.3 recorded
# Station 27042 success: 19.3 recorded
# Station 65034 success: 17.0 recorded
# Station 65035 success: 17.2 recorded
# Station 87065 success: 14.1 recorded
# Station 300003 failure: null value recorded
# Station 61078 success: 15.7 recorded
# Station 9642 success: 17.1 recorded
# Station 16001 success: 19.0 recorded
# Station 85103 success: 13.8 recorded
